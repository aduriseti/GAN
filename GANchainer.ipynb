# %%
import chainer as ch
import chainer.links as L
import chainer.functions as F

import numpy as np
import scipy as sp
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

import os
import PIL

# %% [markdown]
# [impl|test]
# - activation power: prelu > relu > lrelu
#     - generator
#         - [x| ] relu
#         - [ | ] lrelu
#         - [ | ] prelu
#     - discriminator
#         - [ | ] relu
#         - [x| ] lrelu
#         - [ ] prelu
# TRY WEAKENING DISCRIMIATOR BY REPLACING CONV+POOL W/ ONLY STRIDED CONV
#             # does it make sense reducing channels when striding conv? try it both ways
#             # guess it makes sense that more infomation is preserved that way
#             # but don't you want to weaken the discriminator?
#             # REDUCE BEFORE STRIDED CONV - CLOSER ANAGLOGUE TO POOLING
# - discriminator strength: (1) > (2) > (3) > (4)
#     - [ | ] (1) channel expansion before strided convolution
#         32*32*3->32*32*128->16*16*128->16*16*256->
#         8*8*256->8*8*512->4*4*512->4*4*512
#     - [x| ] (2) channel expansion during strided convolution
#         32*32*3->32*32*64->16*16*128->16*16*128->
#         8*8*256->8*8*256->4*4*512->4*4*512
#     - [x| ] (3) channel expansion after strided convolution
#         32*32*3->32*32*64->16*16*64->16*16*128->
#         8*8*128->8*8*256->4*4*512->4*4*512    - [x| ] (4) channel expansion during strided convolution, only strided convolution
#         32*32*3->16*16*64->8*8*128->4*4*256->
# - generator strength: (1) > (2) > (3) > (4)
#     - [ | ] (1) channel compression after strided deconv
#     - [ | ] (2) channel compression during strided deconv
#     - [ | ] (3) channel compression before strided deconv
#     - [x| ] (4) channel compression during strided deconv, only strided deconv
#         4*4*512->8*8*256->16*16*128->32*32->64->32*32*3

# %%
class Generator(ch.Chain):
    def __init__(self,nh=128,d0=4,c0=512,Wscale=0.02):
        self.nh,self.d0,self.c0 = nh,d0,c0
        super(Generator,self).__init__()
        with self.init_scope():
            # WHY NOT ADD NON STRIDED CONVS BETWEEN DECONVS?
            Winit = ch.initializers.Normal(scale=Wscale)
            self.l0 = L.Linear(in_size=nh,out_size=d0*d0*c0,initialW=Winit)
            self.dc1 = L.Deconvolution2D(in_channels=c0,out_channels=c0//2,
                                         ksize=4,stride=2,pad=1,initialW=Winit)
            self.dc2 = L.Deconvolution2D(in_channels=c0//2,out_channels=c0//4,
                                         ksize=4,stride=2,pad=1,initialW=Winit)
            self.dc3 = L.Deconvolution2D(in_channels=c0//4,out_channels=c0//8,
                                         ksize=4,stride=2,pad=1,initialW=Winit)
            self.dc4 = L.Deconvolution2D(in_channels=c0//8,out_channels=3,
                                         ksize=3,stride=1,pad=1,initialW=Winit)
            self.bn0 = L.BatchNormalization(d0*d0*c0)
            self.bn1 = L.BatchNormalization(c0//2)
            self.bn2 = L.BatchNormalization(c0//4)
            self.bn3 = L.BatchNormalization(c0//8)
        
    def hidden_init(self,nb):
        return np.random.uniform(-1,1,(nb,self.nh,1,1)).astype(np.float32)
    
    def __call__(self,z):
        nb,nh,*_ = z.shape
        assert(nh==self.nh)
        h = F.reshape(F.relu(self.bn0(self.l0(z))),
                      (nb,self.c0,self.d0,self.d0))
        # nb*512*4*4 
        h = F.relu(self.bn1(self.dc1(h)))
        # nb*256*8*8
        h = F.relu(self.bn2(self.dc2(h)))
        # nb*128*16*16
        h = F.relu(self.bn3(self.dc3(h)))
        # nb*64*32*32
        return F.sigmoid(self.dc4(h))
        # nb*3*32*32

# %%
def noise(h,sigma=0.2):
    xp = ch.backends.cuda.get_array_module(h.array)
    return h + sigma*xp.random.rand(*h.shape) if ch.config.train else h

# %%
class Discrimiator(ch.Chain):
    def __init__(self,nh=128,df=4,cf=512,Wscale=0.02):
        Winit = ch.initializers.Normal(scale=Wscale)
        super(Discrimiator,self).__init__()
        with self.init_scope():
            self.c0a = L.Convolution2D(in_channels=3,out_channels=cf//8,
                                       ksize=3,stride=1,pad=1,initialW=Winit)
            self.c0b = L.Convolution2D(in_channels=cf//8,out_channels=cf//4,
                                       ksize=4,stride=2,pad=1,initialW=Winit)
            self.c1a = L.Convolution2D(in_channels=cf//4,out_channels=cf//4,
                                       ksize=3,stride=1,pad=1,initialW=Winit)
            self.c1b = L.Convolution2D(in_channels=cf//4,out_channels=cf//2,
                                       ksize=4,stride=2,pad=1,initialW=Winit)
            self.c2a = L.Convolution2D(in_channels=cf//2,out_channels=cf//2,
                                       ksize=3,stride=1,pad=1,initialW=Winit)
            self.c2b = L.Convolution2D(in_channels=cf//2,out_channels=cf,
                                       ksize=4,stride=2,pad=1,initialW=Winit)
            self.c3a = L.Convolution2D(in_channels=cf,out_channels=cf,
                                       ksize=3,stride=1,pad=1,initialW=Winit)
            self.l4 = L.Linear(df*df*cf,1,initialW=Winit)
            # no batch norm for first conv b/c already normalized
            self.bn0b = L.BatchNormalization(cf//4,use_gamma=False)
            self.bn1a = L.BatchNormalization(cf//4,use_gamma=False)
            self.bn1b = L.BatchNormalization(cf//2,use_gamma=False)
            self.bn2a = L.BatchNormalization(cf//2,use_gamma=False)
            self.bn2b = L.BatchNormalization(cf,use_gamma=False)
            self.bn3a = L.BatchNormalization(cf,use_gamma=False)

    def __call__(self,x):                             
        h = noise(x)
        # 32*32*3
        h = F.leaky_relu(noise(self.c0a(h)))
        # 32*32*64
        h = F.leaky_relu(noise(self.bn0b(self.c0b(h))))
        # 16*16*128
        h = F.leaky_relu(noise(self.bn1a(self.c1a(h))))
        # 16*16*128
        h = F.leaky_relu(noise(self.bn1b(self.c1b(h))))
        # 8*8*256
        h = F.leaky_relu(noise(self.bn2a(self.c2a(h))))
        # 8*8*256
        h = F.leaky_relu(noise(self.bn2b(self.c2b(h))))
        # 4*4*512
        h = F.leaky_relu(noise(self.bn3a(self.c3a(h))))
        # 4*4*512
        return self.l4(h)

# %%
class DCGANupdater(ch.training.updaters.StandardUpdater):
    def __init__(self,models=(None,None),*args,**kwargs):
        self.gen,self.dis = models
        assert self.gen != None and self.dis != None
        super(DCGANupdater,self).__init__(*args,**kwargs)
    
    def genLoss(self,yFake):
        nbF,*_ = yFake.shape
        L = F.sum(F.softplus(-yFake))
        L = L / nbF
        ch.report({'loss':L},dis)
        return L
    
    def disLoss(self,yFake,yReal):
        nbF,*_ = yFake.shape
        nbR,*_ = yReal.shape
        L = F.sum(F.softplus(yFake)) + F.sum(F.softplus(-yReal))
#         return L / (nbF + nbR)
        L = L / nbF # in tutorial repo
        ch.report({'loss':L},gen)
        return L
                                             
    def update_core(self):
        genOpt,disOpt = self.get_optimizer('gen'),self.get_optimizer('dis')
        gen,dis = self.gen,self.dis
        
        batch = self.get_iterator('main').next()
        xReal = ch.Variable(self.converter(batch,self.device))/255
        xp = ch.backends.cuda.get_array_module(xReal.array)
        nb,*_ = xReal.shape
        
        z = ch.Variable(xp.asarray(gen.hidden_init(nb)))
        xFake = gen(z)
#         print(xFake.array.shape)
#         print(xReal.array.shape)
        yFake,yReal = dis(xFake),dis(xReal)
        
        genOpt.update(self.genLoss,yFake)
        disOpt.update(self.disLoss,yFake,yReal)

# %%
def sample(gen,dis,rows,cols,seed,out):
    @ch.training.make_extension()
    def sampleImg(trainer):
        np.random.seed(seed)
        nb = rows*cols
        xp = gen.xp
        z = ch.Variable(xp.asarray(gen.hidden_init(nb)))
        with ch.using_config('train',False):
            x = gen(z)
        x = ch.backends.cuda.to_cpu(x.array)
        np.random.seed()
        
        x = np.asarray(np.clip(x*255,0.0,255.0),dtype=np.uint8)
        _,_,H,W = x.shape
        x = x.reshape((rows,cols,3,H,W))
        # turn sampled images into grid
        x = x.transpose(0,3,1,4,2).reshape(rows*H,cols*W,3)
        
        sampleDir = os.path.join(out,'samples')
        if not os.path.exists(sampleDir): os.makedirs(sampleDir)
        samplePath = os.path.join(sampleDir,'sample_iter_{:0>8}.png'.format(trainer.updater.iteration))
        PIL.Image.fromarray(x).save(samplePath)
    return sampleImg

# %%
train,_ = ch.datasets.get_cifar10(withlabel=False,scale=255.)
# imgFiles = [os.path.join(datasetRoot,f) 
#             for f in os.listdir(datasetRoot) 
#             if ('png' in f or 'jpg' in f)]
# train = ch.datasets.ImageDataset(imgFiles)

nb = 32
trainIter = ch.iterators.SerialIterator(train,nb)
gen = Generator()
dis = Discrimiator()
print(gen.count_params(),dis.count_params())

def makeOpt(model,alpha=0.0002,beta1=0.5):
    opt = ch.optimizers.Adam(alpha=alpha,beta1=beta1)
    opt.setup(model)
    opt.add_hook(ch.optimizer_hooks.WeightDecay(0.0001),'hook_dec')
    return opt
genOpt,disOpt = makeOpt(gen),makeOpt(dis)
# Out:
# 3828739 5862657

# %%
dev = -1 # CPU
saveEvery = (100,'iteration')
dispEvery = (10,'iteration')
stopAfter = (1,'epoch')
sampleSeed = 0
snapshotPath = ""
updater = DCGANupdater(models=(gen,dis),
                       iterator=trainIter,
                       optimizer={'gen':genOpt,'dis':disOpt},
                       device=dev)
root = '.'
outdir = os.path.join(root,'results')
if not os.path.exists(outdir): os.mkdir(outdir)
trainer = ch.training.Trainer(updater,stop_trigger=stopAfter,out=outdir)
saveExt = [
    ch.training.extensions.snapshot(filename='snapshot_iter_{.updater.iteration}.npz'),
    ch.training.extensions.snapshot_object(gen,'gen_iter_{.updater.iteration}.npz'),
    ch.training.extensions.snapshot_object(dis,'dis_iter_{.updater.iteration}.npz'),
]
dispExt = [
#     ch.training.extensions.LogReport(),
    ch.training.extensions.PrintReport(['epoch','iteration','gen/loss','dis/loss']),
    ch.training.extensions.PlotReport(['gen/loss','dis/loss'],'iteration',file_name='loss.png'),
#     ch.training.extensions.ProgressBar(),
    sample(gen=gen,dis=dis,rows=10,cols=10,seed=sampleSeed,out=outdir),
]
trainer.extend(ch.training.extensions.ProgressBar(update_interval=10))
trainer.extend(ch.training.extensions.LogReport(trigger=dispEvery))
for ext in saveExt: trainer.extend(extension=ext,trigger=saveEvery)
for ext in dispExt: trainer.extend(extension=ext,trigger=dispEvery)
if snapshotPath:
    ch.serializers.load_npz(snapshotPath,trainer)

# %%
trainer.run()
# Out:
#      total [..................................................]  0.64%
# this epoch [..................................................]  0.64%
#         10 iter, 0 epoch / 1 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
# epoch       iteration   gen/loss    dis/loss
# 0           10          2.59841     1.26126
#      total [..................................................]  1.28%
# this epoch [..................................................]  1.28%
#         20 iter, 0 epoch / 1 epochs
#    0.11129 iters/sec. Estimated time to finish: 3:51:00.171706.
# 0           20          1.62074     1.21432
#      total [..................................................]  1.92%
# this epoch [..................................................]  1.92%
#         30 iter, 0 epoch / 1 epochs
#    0.11263 iters/sec. Estimated time to finish: 3:46:46.363012.
# 0           30          0.724471    2.55863
#      total [#.................................................]  2.56%
# this epoch [#.................................................]  2.56%
#         40 iter, 0 epoch / 1 epochs
#    0.11491 iters/sec. Estimated time to finish: 3:40:49.130402.
# 0           40          0.881113    6.39082
#      total [#.................................................]  3.20%
# this epoch [#.................................................]  3.20%
#         50 iter, 0 epoch / 1 epochs
#    0.11482 iters/sec. Estimated time to finish: 3:39:32.535345.
# 0           50          2.74124     9.71168
#      total [#.................................................]  3.84%
# this epoch [#.................................................]  3.84%
#         60 iter, 0 epoch / 1 epochs
#    0.11439 iters/sec. Estimated time to finish: 3:38:55.107301.
# 0           60          1.69917     7.39665
#      total [##................................................]  4.48%
# this epoch [##................................................]  4.48%
#         70 iter, 0 epoch / 1 epochs
#    0.11518 iters/sec. Estimated time to finish: 3:35:57.787241.
# 0           70          0.245166    3.95876
#      total [##................................................]  5.12%
# this epoch [##................................................]  5.12%
#         80 iter, 0 epoch / 1 epochs
#    0.11599 iters/sec. Estimated time to finish: 3:33:01.163850.
# 0           80          1.48642     2.55802
#      total [##................................................]  5.76%
# this epoch [##................................................]  5.76%
#         90 iter, 0 epoch / 1 epochs
#    0.11684 iters/sec. Estimated time to finish: 3:30:02.689763.
# 0           90          1.07902     2.0702
#      total [###...............................................]  6.40%
# this epoch [###...............................................]  6.40%
#        100 iter, 0 epoch / 1 epochs
#    0.11746 iters/sec. Estimated time to finish: 3:27:30.851577.
# 0           100         1.04214     2.5662
#      total [###...............................................]  7.04%
# this epoch [###...............................................]  7.04%
#        110 iter, 0 epoch / 1 epochs
#    0.11431 iters/sec. Estimated time to finish: 3:31:46.221783.
# 0           110         1.05616     2.11252
#      total [###...............................................]  7.68%
# this epoch [###...............................................]  7.68%
#        120 iter, 0 epoch / 1 epochs
#    0.11442 iters/sec. Estimated time to finish: 3:30:06.765074.
# 0           120         1.01375     1.97114
#      total [####..............................................]  8.32%
# this epoch [####..............................................]  8.32%
#        130 iter, 0 epoch / 1 epochs
#    0.11513 iters/sec. Estimated time to finish: 3:27:22.065093.
# 0           130         1.01504     1.84018
#      total [####..............................................]  8.96%
# this epoch [####..............................................]  8.96%
#        140 iter, 0 epoch / 1 epochs
#    0.11569 iters/sec. Estimated time to finish: 3:24:56.110255.
# 0           140         0.748267    2.19629
#      total [####..............................................]  9.60%
# this epoch [####..............................................]  9.60%
#        150 iter, 0 epoch / 1 epochs
#    0.11595 iters/sec. Estimated time to finish: 3:23:02.401744.
# 0           150         0.570818    2.81519
#      total [#####.............................................] 10.24%
# this epoch [#####.............................................] 10.24%
#        160 iter, 0 epoch / 1 epochs
#     0.1163 iters/sec. Estimated time to finish: 3:20:59.095657.
# 0           160         0.918163    3.23842
#      total [#####.............................................] 10.88%
# this epoch [#####.............................................] 10.88%
#        170 iter, 0 epoch / 1 epochs
#    0.11664 iters/sec. Estimated time to finish: 3:18:58.273419.
# 0           170         0.758654    2.50367
#      total [#####.............................................] 11.52%
# this epoch [#####.............................................] 11.52%
#        180 iter, 0 epoch / 1 epochs
#    0.11731 iters/sec. Estimated time to finish: 3:16:24.889640.
# 0           180         0.405096    2.92394
#      total [######............................................] 12.16%
# this epoch [######............................................] 12.16%
#        190 iter, 0 epoch / 1 epochs
#     0.1179 iters/sec. Estimated time to finish: 3:14:00.923677.
# 0           190         1.0242      2.19872
#      total [######............................................] 12.80%
# this epoch [######............................................] 12.80%
#        200 iter, 0 epoch / 1 epochs
#    0.11841 iters/sec. Estimated time to finish: 3:11:46.298179.
# 0           200         1.10763     2.07757
#      total [######............................................] 13.44%
# this epoch [######............................................] 13.44%
#        210 iter, 0 epoch / 1 epochs
#    0.11693 iters/sec. Estimated time to finish: 3:12:46.839640.
# 0           210         1.18158     1.72347
#      total [#######...........................................] 14.08%
# this epoch [#######...........................................] 14.08%
#        220 iter, 0 epoch / 1 epochs
#    0.11718 iters/sec. Estimated time to finish: 3:10:56.909044.
# 0           220         1.03318     1.75157
#      total [#######...........................................] 14.72%
# this epoch [#######...........................................] 14.72%
#        230 iter, 0 epoch / 1 epochs
#    0.11751 iters/sec. Estimated time to finish: 3:08:59.079613.
# 0           230         1.32817     1.75441
#      total [#######...........................................] 15.36%
# this epoch [#######...........................................] 15.36%
#        240 iter, 0 epoch / 1 epochs
#    0.11758 iters/sec. Estimated time to finish: 3:07:28.021252.
# 0           240         1.36566     1.85052
#      total [########..........................................] 16.00%
# this epoch [########..........................................] 16.00%
#        250 iter, 0 epoch / 1 epochs
#    0.11781 iters/sec. Estimated time to finish: 3:05:40.358157.
# 0           250         1.25897     2.04659
#      total [########..........................................] 16.64%
# this epoch [########..........................................] 16.64%
#        260 iter, 0 epoch / 1 epochs
#    0.11809 iters/sec. Estimated time to finish: 3:03:49.490407.
# 0           260         1.1015      1.46853
#      total [########..........................................] 17.28%
# this epoch [########..........................................] 17.28%
#        270 iter, 0 epoch / 1 epochs
#    0.11846 iters/sec. Estimated time to finish: 3:01:51.131993.
# 0           270         0.908668    1.63341
#      total [########..........................................] 17.92%
# this epoch [########..........................................] 17.92%
#        280 iter, 0 epoch / 1 epochs
#    0.11882 iters/sec. Estimated time to finish: 2:59:54.048518.
# 0           280         1.30513     2.37955
#      total [#########.........................................] 18.56%
# this epoch [#########.........................................] 18.56%
#        290 iter, 0 epoch / 1 epochs
#    0.11911 iters/sec. Estimated time to finish: 2:58:03.160202.
# 0           290         1.02604     1.90663
#      total [#########.........................................] 19.20%
# this epoch [#########.........................................] 19.20%
#        300 iter, 0 epoch / 1 epochs
#    0.11933 iters/sec. Estimated time to finish: 2:56:19.846459.
# 0           300         1.05485     1.68099
#      total [#########.........................................] 19.84%
# this epoch [#########.........................................] 19.84%
#        310 iter, 0 epoch / 1 epochs
#    0.11833 iters/sec. Estimated time to finish: 2:56:24.928856.
# 0           310         0.759076    1.89499
#      total [##########........................................] 20.48%
# this epoch [##########........................................] 20.48%
#        320 iter, 0 epoch / 1 epochs
#    0.11855 iters/sec. Estimated time to finish: 2:54:40.832711.
# 0           320         0.984086    2.13688
#      total [##########........................................] 21.12%
# this epoch [##########........................................] 21.12%
#        330 iter, 0 epoch / 1 epochs
#    0.10339 iters/sec. Estimated time to finish: 3:18:41.424449.
# 0           330         0.812226    2.00424
#      total [##########........................................] 21.76%
# this epoch [##########........................................] 21.76%
#        340 iter, 0 epoch / 1 epochs
#    0.10353 iters/sec. Estimated time to finish: 3:16:48.438934.
# 0           340         0.706666    2.46932
#      total [###########.......................................] 22.40%
# this epoch [###########.......................................] 22.40%
#        350 iter, 0 epoch / 1 epochs
#    0.10395 iters/sec. Estimated time to finish: 3:14:24.516376.
# 0           350         1.01264     2.56166
#      total [###########.......................................] 23.04%
# this epoch [###########.......................................] 23.04%
#        360 iter, 0 epoch / 1 epochs
#    0.10446 iters/sec. Estimated time to finish: 3:11:51.589162.
# 0           360         0.782662    2.36328
#      total [###########.......................................] 23.68%
# this epoch [###########.......................................] 23.68%
#        370 iter, 0 epoch / 1 epochs
#    0.10489 iters/sec. Estimated time to finish: 3:09:28.682496.
# 0           370         0.561631    2.50677
#      total [############......................................] 24.32%
# this epoch [############......................................] 24.32%
#        380 iter, 0 epoch / 1 epochs
#    0.10532 iters/sec. Estimated time to finish: 3:07:08.210473.
# 0           380         0.730292    3.46183
#      total [############......................................] 24.96%
# this epoch [############......................................] 24.96%
#        390 iter, 0 epoch / 1 epochs
#    0.10571 iters/sec. Estimated time to finish: 3:04:51.746586.
# 0           390         0.81671     1.99212
#      total [############......................................] 25.60%
# this epoch [############......................................] 25.60%
#        400 iter, 0 epoch / 1 epochs
#    0.10606 iters/sec. Estimated time to finish: 3:02:40.829087.
# 0           400         1.39205     2.3052
#      total [#############.....................................] 26.24%
# this epoch [#############.....................................] 26.24%
#        410 iter, 0 epoch / 1 epochs
#    0.10568 iters/sec. Estimated time to finish: 3:01:45.664620.
# 0           410         0.707047    2.23382
#      total [#############.....................................] 26.88%
# this epoch [#############.....................................] 26.88%
#        420 iter, 0 epoch / 1 epochs
#    0.10602 iters/sec. Estimated time to finish: 2:59:36.070600.
# 0           420         0.564714    2.13766
#      total [#############.....................................] 27.52%
# this epoch [#############.....................................] 27.52%
#        430 iter, 0 epoch / 1 epochs
#    0.10637 iters/sec. Estimated time to finish: 2:57:27.129929.
# 0           430         0.960597    2.30727
#      total [##############....................................] 28.16%
# this epoch [##############....................................] 28.16%
#        440 iter, 0 epoch / 1 epochs
#    0.10671 iters/sec. Estimated time to finish: 2:55:19.414306.
# 0           440         0.882964    1.87863
#      total [##############....................................] 28.80%
# this epoch [##############....................................] 28.80%
#        450 iter, 0 epoch / 1 epochs
#      0.107 iters/sec. Estimated time to finish: 2:53:17.596795.
# 0           450         0.500715    3.06345
#      total [##############....................................] 29.44%
# this epoch [##############....................................] 29.44%
#        460 iter, 0 epoch / 1 epochs
#    0.10689 iters/sec. Estimated time to finish: 2:51:54.442077.
# 0           460         0.988456    3.26708
#      total [###############...................................] 30.08%
# this epoch [###############...................................] 30.08%
#        470 iter, 0 epoch / 1 epochs
#    0.10727 iters/sec. Estimated time to finish: 2:49:44.127894.
# 0           470         0.744266    2.068
#      total [###############...................................] 30.72%
# this epoch [###############...................................] 30.72%
#        480 iter, 0 epoch / 1 epochs
#    0.10761 iters/sec. Estimated time to finish: 2:47:39.075329.
# 0           480         0.651532    2.66483
#      total [###############...................................] 31.36%
# this epoch [###############...................................] 31.36%
#        490 iter, 0 epoch / 1 epochs
#    0.10799 iters/sec. Estimated time to finish: 2:45:31.339860.
# 0           490         0.596338    2.14699
#      total [################..................................] 32.00%
# this epoch [################..................................] 32.00%
#        500 iter, 0 epoch / 1 epochs
#    0.10825 iters/sec. Estimated time to finish: 2:43:35.346473.
# 0           500         1.20402     2.9642
#      total [################..................................] 32.64%
# this epoch [################..................................] 32.64%
#        510 iter, 0 epoch / 1 epochs
#    0.10792 iters/sec. Estimated time to finish: 2:42:32.357531.
# 0           510         0.754319    2.49111
#      total [################..................................] 33.28%
# this epoch [################..................................] 33.28%
#        520 iter, 0 epoch / 1 epochs
#    0.10824 iters/sec. Estimated time to finish: 2:40:31.721477.
# 0           520         0.809275    2.28692
#      total [################..................................] 33.92%
# this epoch [################..................................] 33.92%
#        530 iter, 0 epoch / 1 epochs
#    0.10854 iters/sec. Estimated time to finish: 2:38:32.885493.
# 0           530         0.860533    2.71754
#      total [#################.................................] 34.56%
# this epoch [#################.................................] 34.56%
#        540 iter, 0 epoch / 1 epochs
#    0.10942 iters/sec. Estimated time to finish: 2:35:44.457271.
# 0           540         0.883827    2.15672
#      total [#################.................................] 35.20%
# this epoch [#################.................................] 35.20%
#        550 iter, 0 epoch / 1 epochs
#    0.10969 iters/sec. Estimated time to finish: 2:33:50.589533.
# 0           550         0.615772    2.63025
#      total [#################.................................] 35.84%
# this epoch [#################.................................] 35.84%
#        560 iter, 0 epoch / 1 epochs
#    0.10985 iters/sec. Estimated time to finish: 2:32:05.736342.
# 0           560         0.849273    2.60601
#      total [##################................................] 36.48%
# this epoch [##################................................] 36.48%
#        570 iter, 0 epoch / 1 epochs
#    0.11009 iters/sec. Estimated time to finish: 2:30:15.245157.
# 0           570         0.739402    2.31979
#      total [##################................................] 37.12%
# this epoch [##################................................] 37.12%
#        580 iter, 0 epoch / 1 epochs
#    0.11031 iters/sec. Estimated time to finish: 2:28:26.460159.
# 0           580         0.474277    2.68185
#      total [##################................................] 37.76%
# this epoch [##################................................] 37.76%
#        590 iter, 0 epoch / 1 epochs
#    0.11037 iters/sec. Estimated time to finish: 2:26:51.119061.
# 0           590         0.58772     2.63993
#      total [###################...............................] 38.40%
# this epoch [###################...............................] 38.40%
#        600 iter, 0 epoch / 1 epochs
#    0.11063 iters/sec. Estimated time to finish: 2:25:00.405915.
# 0           600         0.942211    2.75702
#      total [###################...............................] 39.04%
# this epoch [###################...............................] 39.04%
#        610 iter, 0 epoch / 1 epochs
#    0.11028 iters/sec. Estimated time to finish: 2:23:57.410413.
# 0           610         1.11119     2.60979
#      total [###################...............................] 39.68%
# this epoch [###################...............................] 39.68%
#        620 iter, 0 epoch / 1 epochs
#    0.11027 iters/sec. Estimated time to finish: 2:22:27.545771.
# 0           620         0.702327    2.53598
#      total [####################..............................] 40.32%
# this epoch [####################..............................] 40.32%
#        630 iter, 0 epoch / 1 epochs
#    0.11031 iters/sec. Estimated time to finish: 2:20:53.378063.
# 0           630         0.668916    2.29395
#      total [####################..............................] 40.96%
# this epoch [####################..............................] 40.96%
#        640 iter, 0 epoch / 1 epochs
#    0.11028 iters/sec. Estimated time to finish: 2:19:25.264002.
# 0           640         1.14027     3.59552
#      total [####################..............................] 41.60%
# this epoch [####################..............................] 41.60%
#        650 iter, 0 epoch / 1 epochs
#    0.11032 iters/sec. Estimated time to finish: 2:17:51.068841.
# 0           650         0.945825    2.15875
#      total [#####################.............................] 42.24%
# this epoch [#####################.............................] 42.24%
#        660 iter, 0 epoch / 1 epochs
#     0.1105 iters/sec. Estimated time to finish: 2:16:07.319144.
# 0           660         0.868001    1.98001
#      total [#####################.............................] 42.88%
# this epoch [#####################.............................] 42.88%
#        670 iter, 0 epoch / 1 epochs
#    0.11061 iters/sec. Estimated time to finish: 2:14:28.767510.
# 0           670         0.538774    2.40008
#      total [#####################.............................] 43.52%
# this epoch [#####################.............................] 43.52%
#        680 iter, 0 epoch / 1 epochs
#    0.11079 iters/sec. Estimated time to finish: 2:12:45.636661.
# 0           680         0.798868    2.23991
#      total [######################............................] 44.16%
# this epoch [######################............................] 44.16%
#        690 iter, 0 epoch / 1 epochs
#    0.11093 iters/sec. Estimated time to finish: 2:11:04.989774.
# 0           690         0.96152     2.30463
#      total [######################............................] 44.80%
# this epoch [######################............................] 44.80%
#        700 iter, 0 epoch / 1 epochs
#    0.11108 iters/sec. Estimated time to finish: 2:09:24.602917.
# 0           700         0.918494    2.66277
#      total [######################............................] 45.44%
# this epoch [######################............................] 45.44%
#        710 iter, 0 epoch / 1 epochs
#     0.1108 iters/sec. Estimated time to finish: 2:08:14.215392.
# 0           710         0.808472    2.23093
#      total [#######################...........................] 46.08%
# this epoch [#######################...........................] 46.08%
#        720 iter, 0 epoch / 1 epochs
#    0.11096 iters/sec. Estimated time to finish: 2:06:32.661878.
# 0           720         0.842855    2.42635
#      total [#######################...........................] 46.72%
# this epoch [#######################...........................] 46.72%
#        730 iter, 0 epoch / 1 epochs
#    0.11113 iters/sec. Estimated time to finish: 2:04:50.898505.
# 0           730         0.591409    3.32733
#      total [#######################...........................] 47.36%
# this epoch [#######################...........................] 47.36%
#        740 iter, 0 epoch / 1 epochs
#    0.11128 iters/sec. Estimated time to finish: 2:03:11.156941.
# 0           740         0.688108    2.52129
#      total [########################..........................] 48.00%
# this epoch [########################..........................] 48.00%
#        750 iter, 0 epoch / 1 epochs
#    0.11131 iters/sec. Estimated time to finish: 2:01:39.131997.
# 0           750         0.786453    2.1798
#      total [########################..........................] 48.64%
# this epoch [########################..........................] 48.64%
#        760 iter, 0 epoch / 1 epochs
#    0.11139 iters/sec. Estimated time to finish: 2:00:04.104112.
# 0           760         0.95139     2.04163
#      total [########################..........................] 49.28%
# this epoch [########################..........................] 49.28%
#        770 iter, 0 epoch / 1 epochs
#    0.11113 iters/sec. Estimated time to finish: 1:58:51.022542.
# 0           770         1.04923     2.6638
#      total [########################..........................] 49.92%
# this epoch [########################..........................] 49.92%
#        780 iter, 0 epoch / 1 epochs
#    0.11095 iters/sec. Estimated time to finish: 1:57:32.693482.
# 0           780         1.01219     2.45036
#      total [#########################.........................] 50.56%
# this epoch [#########################.........................] 50.56%
#        790 iter, 0 epoch / 1 epochs
#    0.11088 iters/sec. Estimated time to finish: 1:56:07.272549.
# 0           790         0.814072    2.21416
#      total [#########################.........................] 51.20%
# this epoch [#########################.........................] 51.20%
#        800 iter, 0 epoch / 1 epochs
#    0.11084 iters/sec. Estimated time to finish: 1:54:39.515549.
# 0           800         0.690473    2.22263
#      total [#########################.........................] 51.84%
# this epoch [#########################.........................] 51.84%
#        810 iter, 0 epoch / 1 epochs
#    0.11044 iters/sec. Estimated time to finish: 1:53:33.390449.
# 0           810         0.603935    2.34884
#      total [##########################........................] 52.48%
# this epoch [##########################........................] 52.48%
#        820 iter, 0 epoch / 1 epochs
#    0.11059 iters/sec. Estimated time to finish: 1:51:54.237883.
# 0           820         1.24543     2.7917
#      total [##########################........................] 53.12%
# this epoch [##########################........................] 53.12%
#        830 iter, 0 epoch / 1 epochs
#     0.1107 iters/sec. Estimated time to finish: 1:50:17.226694.
# 0           830         0.870555    2.06402
#      total [##########################........................] 53.76%
# this epoch [##########################........................] 53.76%
#        840 iter, 0 epoch / 1 epochs
#    0.11074 iters/sec. Estimated time to finish: 1:48:44.251662.
# 0           840         0.863576    1.95304
#      total [###########################.......................] 54.40%
# this epoch [###########################.......................] 54.40%
#        850 iter, 0 epoch / 1 epochs
#    0.11076 iters/sec. Estimated time to finish: 1:47:13.048603.
# 0           850         1.35164     1.91182
#      total [###########################.......................] 55.04%
# this epoch [###########################.......................] 55.04%
#        860 iter, 0 epoch / 1 epochs
#    0.11067 iters/sec. Estimated time to finish: 1:45:47.969938.
# 0           860         0.739063    2.09047
#      total [###########################.......................] 55.68%
# this epoch [###########################.......................] 55.68%
#        870 iter, 0 epoch / 1 epochs
#    0.11055 iters/sec. Estimated time to finish: 1:44:24.050479.
# 0           870         1.03173     2.34808
#      total [############################......................] 56.32%
# this epoch [############################......................] 56.32%
#        880 iter, 0 epoch / 1 epochs
#    0.11053 iters/sec. Estimated time to finish: 1:42:54.978006.
# 0           880         0.90406     1.68641
#      total [############################......................] 56.96%
# this epoch [############################......................] 56.96%
#        890 iter, 0 epoch / 1 epochs
#     0.1106 iters/sec. Estimated time to finish: 1:41:20.403706.
# 0           890         1.01621     1.74038
#      total [############################......................] 57.60%
# this epoch [############################......................] 57.60%
#        900 iter, 0 epoch / 1 epochs
#    0.11059 iters/sec. Estimated time to finish: 1:39:50.668786.
# 0           900         0.777028    1.62724
#      total [#############################.....................] 58.24%
# this epoch [#############################.....................] 58.24%
#        910 iter, 0 epoch / 1 epochs
#    0.11018 iters/sec. Estimated time to finish: 1:38:42.253031.
# 0           910         0.787283    2.30921
#      total [#############################.....................] 58.88%
# this epoch [#############################.....................] 58.88%
#        920 iter, 0 epoch / 1 epochs
#    0.10963 iters/sec. Estimated time to finish: 1:37:40.529410.
# 0           920         1.25547     1.80238
#      total [#############################.....................] 59.52%
# this epoch [#############################.....................] 59.52%
#        930 iter, 0 epoch / 1 epochs
#    0.10966 iters/sec. Estimated time to finish: 1:36:07.744583.
# 0           930         0.884195    1.65459
#      total [##############################....................] 60.16%
# this epoch [##############################....................] 60.16%
#        940 iter, 0 epoch / 1 epochs
#    0.10974 iters/sec. Estimated time to finish: 1:34:32.722252.
# 0           940         1.09036     1.47625
#      total [##############################....................] 60.80%
# this epoch [##############################....................] 60.80%
#        950 iter, 0 epoch / 1 epochs
#     0.1096 iters/sec. Estimated time to finish: 1:33:08.286649.
# 0           950         0.911307    1.86467
#      total [##############################....................] 61.44%
# this epoch [##############################....................] 61.44%
#        960 iter, 0 epoch / 1 epochs
#    0.10969 iters/sec. Estimated time to finish: 1:31:32.663997.
# 0           960         0.843409    1.61275
#      total [###############################...................] 62.08%
# this epoch [###############################...................] 62.08%
#        970 iter, 0 epoch / 1 epochs
#     0.1096 iters/sec. Estimated time to finish: 1:30:05.942473.
# 0           970         0.827205    1.75104
#      total [###############################...................] 62.72%
# this epoch [###############################...................] 62.72%
#        980 iter, 0 epoch / 1 epochs
#    0.10966 iters/sec. Estimated time to finish: 1:28:31.952581.
# 0           980         0.987603    1.89947
#      total [###############################...................] 63.36%
# this epoch [###############################...................] 63.36%
#        990 iter, 0 epoch / 1 epochs
#    0.10968 iters/sec. Estimated time to finish: 1:26:59.962856.
# 0           990         1.28657     1.31342
#      total [################################..................] 64.00%
# this epoch [################################..................] 64.00%
#       1000 iter, 0 epoch / 1 epochs
#    0.10974 iters/sec. Estimated time to finish: 1:25:25.806199.
# 0           1000        1.10678     1.81012
#      total [################################..................] 64.64%
# this epoch [################################..................] 64.64%
#       1010 iter, 0 epoch / 1 epochs
#    0.10943 iters/sec. Estimated time to finish: 1:24:09.101998.
# 0           1010        0.802155    1.65006
#      total [################################..................] 65.28%
# this epoch [################################..................] 65.28%
#       1020 iter, 0 epoch / 1 epochs
#    0.10939 iters/sec. Estimated time to finish: 1:22:39.270327.
# 0           1020        0.864055    1.63642
#      total [################################..................] 65.92%
# this epoch [################################..................] 65.92%
#       1030 iter, 0 epoch / 1 epochs
#    0.10927 iters/sec. Estimated time to finish: 1:21:13.149195.
# 0           1030        0.835838    1.91363
#      total [#################################.................] 66.56%
# this epoch [#################################.................] 66.56%
#       1040 iter, 0 epoch / 1 epochs
#    0.10901 iters/sec. Estimated time to finish: 1:19:52.980428.
# 0           1040        1.27739     2.03291
#      total [#################################.................] 67.20%
# this epoch [#################################.................] 67.20%
#       1050 iter, 0 epoch / 1 epochs
#    0.10906 iters/sec. Estimated time to finish: 1:18:19.299531.
# 0           1050        0.779897    1.72291
#      total [#################################.................] 67.84%
# this epoch [#################################.................] 67.84%
#       1060 iter, 0 epoch / 1 epochs
#    0.10885 iters/sec. Estimated time to finish: 1:16:56.605301.
# 0           1060        1.04215     1.83075
#      total [##################################................] 68.48%
# this epoch [##################################................] 68.48%
#       1070 iter, 0 epoch / 1 epochs
#    0.10867 iters/sec. Estimated time to finish: 1:15:31.988659.
# 0           1070        0.885171    1.89076
#      total [##################################................] 69.12%
# this epoch [##################################................] 69.12%
#       1080 iter, 0 epoch / 1 epochs
#    0.10847 iters/sec. Estimated time to finish: 1:14:08.172073.
# 0           1080        0.85696     2.24413
#      total [##################################................] 69.76%
# this epoch [##################################................] 69.76%
#       1090 iter, 0 epoch / 1 epochs
#    0.10847 iters/sec. Estimated time to finish: 1:12:36.019636.
# 0           1090        0.846351    2.17881
#      total [###################################...............] 70.40%
# this epoch [###################################...............] 70.40%
#       1100 iter, 0 epoch / 1 epochs
#    0.10848 iters/sec. Estimated time to finish: 1:11:03.449203.
# 0           1100        0.815741    2.0866
#      total [###################################...............] 71.04%
# this epoch [###################################...............] 71.04%
#       1110 iter, 0 epoch / 1 epochs
#     0.1085 iters/sec. Estimated time to finish: 1:09:30.565384.
# 0           1110        0.830105    2.36383
#      total [###################################...............] 71.68%
# this epoch [###################################...............] 71.68%
#       1120 iter, 0 epoch / 1 epochs
#    0.10837 iters/sec. Estimated time to finish: 1:08:03.254733.
# 0           1120        0.857186    1.62333
#      total [####################################..............] 72.32%
# this epoch [####################################..............] 72.32%
#       1130 iter, 0 epoch / 1 epochs
#    0.10818 iters/sec. Estimated time to finish: 1:06:37.856193.
# 0           1130        1.06644     1.99221
#      total [####################################..............] 72.96%
# this epoch [####################################..............] 72.96%
#       1140 iter, 0 epoch / 1 epochs
#    0.10812 iters/sec. Estimated time to finish: 1:05:07.720863.
# 0           1140        0.81051     1.99046
#      total [####################################..............] 73.60%
# this epoch [####################################..............] 73.60%
#       1150 iter, 0 epoch / 1 epochs
#    0.10809 iters/sec. Estimated time to finish: 1:03:36.216046.
# 0           1150        0.841871    1.88676
#      total [#####################################.............] 74.24%
# this epoch [#####################################.............] 74.24%
#       1160 iter, 0 epoch / 1 epochs
#    0.10793 iters/sec. Estimated time to finish: 1:02:09.122002.
# 0           1160        1.1614      1.88535
#      total [#####################################.............] 74.88%
# this epoch [#####################################.............] 74.88%
#       1170 iter, 0 epoch / 1 epochs
#    0.10789 iters/sec. Estimated time to finish: 1:00:37.911063.
# 0           1170        0.87766     1.79296
#      total [#####################################.............] 75.52%
# this epoch [#####################################.............] 75.52%
#       1180 iter, 0 epoch / 1 epochs
#    0.10778 iters/sec. Estimated time to finish: 0:59:09.035079.
# 0           1180        1.04337     1.73186
#      total [######################################............] 76.16%
# this epoch [######################################............] 76.16%
#       1190 iter, 0 epoch / 1 epochs
#     0.1077 iters/sec. Estimated time to finish: 0:57:38.610789.
# 0           1190        0.783371    1.78887
#      total [######################################............] 76.80%
# this epoch [######################################............] 76.80%
#       1200 iter, 0 epoch / 1 epochs
#    0.10751 iters/sec. Estimated time to finish: 0:56:11.739755.
# 0           1200        1.12091     2.17566
#      total [######################################............] 77.44%
# this epoch [######################################............] 77.44%
#       1210 iter, 0 epoch / 1 epochs
#    0.10747 iters/sec. Estimated time to finish: 0:54:39.951763.
# 0           1210        0.715788    1.57719
#      total [#######################################...........] 78.08%
# this epoch [#######################################...........] 78.08%
#       1220 iter, 0 epoch / 1 epochs
#    0.10737 iters/sec. Estimated time to finish: 0:53:09.802229.
# 0           1220        0.603387    2.25254
#      total [#######################################...........] 78.72%
# this epoch [#######################################...........] 78.72%
#       1230 iter, 0 epoch / 1 epochs
#    0.10733 iters/sec. Estimated time to finish: 0:51:37.912355.
# 0           1230        0.555961    2.12857
#      total [#######################################...........] 79.36%
# this epoch [#######################################...........] 79.36%
#       1240 iter, 0 epoch / 1 epochs
#    0.10732 iters/sec. Estimated time to finish: 0:50:05.072239.
# 0           1240        1.00444     2.85265
#      total [########################################..........] 80.00%
# this epoch [########################################..........] 80.00%
#       1250 iter, 0 epoch / 1 epochs
#    0.10716 iters/sec. Estimated time to finish: 0:48:36.118083.
# 0           1250        0.689766    2.16611
#      total [########################################..........] 80.64%
# this epoch [########################################..........] 80.64%
#       1260 iter, 0 epoch / 1 epochs
#     0.1071 iters/sec. Estimated time to finish: 0:47:04.339043.
# 0           1260        0.848191    1.82536
#      total [########################################..........] 81.28%
# this epoch [########################################..........] 81.28%
#       1270 iter, 0 epoch / 1 epochs
#    0.10694 iters/sec. Estimated time to finish: 0:45:35.236408.
# 0           1270        1.01047     1.80211
#      total [########################################..........] 81.92%
# this epoch [########################################..........] 81.92%
#       1280 iter, 0 epoch / 1 epochs
#    0.10684 iters/sec. Estimated time to finish: 0:44:04.109277.
# 0           1280        0.83184     1.84556
#      total [#########################################.........] 82.56%
# this epoch [#########################################.........] 82.56%
#       1290 iter, 0 epoch / 1 epochs
#    0.10667 iters/sec. Estimated time to finish: 0:42:34.683344.
# 0           1290        0.817222    1.9122
#      total [#########################################.........] 83.20%
# this epoch [#########################################.........] 83.20%
#       1300 iter, 0 epoch / 1 epochs
#    0.10659 iters/sec. Estimated time to finish: 0:41:02.719269.
# 0           1300        0.654164    2.38992
#      total [#########################################.........] 83.84%
# this epoch [#########################################.........] 83.84%
#       1310 iter, 0 epoch / 1 epochs
#     0.1065 iters/sec. Estimated time to finish: 0:39:30.868518.
# 0           1310        1.02042     2.32226
#      total [##########################################........] 84.48%
# this epoch [##########################################........] 84.48%
#       1320 iter, 0 epoch / 1 epochs
#    0.10643 iters/sec. Estimated time to finish: 0:37:58.457133.
# 0           1320        1.0806      1.54271
#      total [##########################################........] 85.12%
# this epoch [##########################################........] 85.12%
#       1330 iter, 0 epoch / 1 epochs
#    0.11117 iters/sec. Estimated time to finish: 0:34:51.385359.
# 0           1330        1.07803     1.84916
#      total [##########################################........] 85.76%
# this epoch [##########################################........] 85.76%
#       1340 iter, 0 epoch / 1 epochs
#    0.11132 iters/sec. Estimated time to finish: 0:33:18.779020.
# 0           1340        0.710146    1.65111
#      total [###########################################.......] 86.40%
# this epoch [###########################################.......] 86.40%
#       1350 iter, 0 epoch / 1 epochs
#    0.11132 iters/sec. Estimated time to finish: 0:31:48.947370.
# 0           1350        1.06948     1.9032
#      total [###########################################.......] 87.04%
# this epoch [###########################################.......] 87.04%
#       1360 iter, 0 epoch / 1 epochs
#    0.11132 iters/sec. Estimated time to finish: 0:30:19.093239.
# 0           1360        0.856223    1.81256
#      total [###########################################.......] 87.68%
# this epoch [###########################################.......] 87.68%
#       1370 iter, 0 epoch / 1 epochs
#    0.11135 iters/sec. Estimated time to finish: 0:28:48.777848.
# 0           1370        0.957366    2.09123
#      total [############################################......] 88.32%
# this epoch [############################################......] 88.32%
#       1380 iter, 0 epoch / 1 epochs
#    0.11138 iters/sec. Estimated time to finish: 0:27:18.572789.
# 0           1380        0.787597    2.15178
#      total [############################################......] 88.96%
# this epoch [############################################......] 88.96%
#       1390 iter, 0 epoch / 1 epochs
#    0.11141 iters/sec. Estimated time to finish: 0:25:48.316992.
# 0           1390        0.804754    2.15089
#      total [############################################......] 89.60%
# this epoch [############################################......] 89.60%
#       1400 iter, 0 epoch / 1 epochs
#    0.11145 iters/sec. Estimated time to finish: 0:24:18.076469.
# 0           1400        0.835221    2.61406
#      total [#############################################.....] 90.24%
# this epoch [#############################################.....] 90.24%
#       1410 iter, 0 epoch / 1 epochs
#    0.11148 iters/sec. Estimated time to finish: 0:22:48.003591.
# 0           1410        0.833918    1.74409
#      total [#############################################.....] 90.88%
# this epoch [#############################################.....] 90.88%
#       1420 iter, 0 epoch / 1 epochs
#    0.11151 iters/sec. Estimated time to finish: 0:21:17.877868.
# 0           1420        1.3159      1.83581
#      total [#############################################.....] 91.52%
# this epoch [#############################################.....] 91.52%
#       1430 iter, 0 epoch / 1 epochs
#    0.11154 iters/sec. Estimated time to finish: 0:19:47.878256.
# 0           1430        1.28098     1.37974
#      total [##############################################....] 92.16%
# this epoch [##############################################....] 92.16%
#       1440 iter, 0 epoch / 1 epochs
#    0.11157 iters/sec. Estimated time to finish: 0:18:17.987932.
# 0           1440        0.930317    1.36745
#      total [##############################################....] 92.80%
# this epoch [##############################################....] 92.80%
#       1450 iter, 0 epoch / 1 epochs
#    0.11162 iters/sec. Estimated time to finish: 0:16:47.909568.
# 0           1450        0.771526    1.60412
#      total [##############################################....] 93.44%
# this epoch [##############################################....] 93.44%
#       1460 iter, 0 epoch / 1 epochs
#    0.11184 iters/sec. Estimated time to finish: 0:15:16.511328.
# 0           1460        0.840329    1.98154
#      total [###############################################...] 94.08%
# this epoch [###############################################...] 94.08%
#       1470 iter, 0 epoch / 1 epochs
#    0.11182 iters/sec. Estimated time to finish: 0:13:47.248298.
# 0           1470        1.35678     1.73212
#      total [###############################################...] 94.72%
# this epoch [###############################################...] 94.72%
#       1480 iter, 0 epoch / 1 epochs
#    0.11181 iters/sec. Estimated time to finish: 0:12:17.876149.
# 0           1480        0.930303    1.46731
#      total [###############################################...] 95.36%
# this epoch [###############################################...] 95.36%
#       1490 iter, 0 epoch / 1 epochs
#    0.11178 iters/sec. Estimated time to finish: 0:10:48.619701.
# 0           1490        0.835634    2.17007
#      total [################################################..] 96.00%
# this epoch [################################################..] 96.00%
#       1500 iter, 0 epoch / 1 epochs
#    0.11181 iters/sec. Estimated time to finish: 0:09:18.979195.
# 0           1500        1.07358     1.77271
#      total [################################################..] 96.64%
# this epoch [################################################..] 96.64%
#       1510 iter, 0 epoch / 1 epochs
#    0.11183 iters/sec. Estimated time to finish: 0:07:49.467019.
# 0           1510        1.08665     1.42566
#      total [################################################..] 97.28%
# this epoch [################################################..] 97.28%
#       1520 iter, 0 epoch / 1 epochs
#    0.11182 iters/sec. Estimated time to finish: 0:06:20.073760.
# 0           1520        1.06101     1.73099
#      total [################################################..] 97.92%
# this epoch [################################################..] 97.92%
#       1530 iter, 0 epoch / 1 epochs
#    0.11182 iters/sec. Estimated time to finish: 0:04:50.653621.
# 0           1530        0.733519    1.87563
#      total [#################################################.] 98.56%
# this epoch [#################################################.] 98.56%
#       1540 iter, 0 epoch / 1 epochs
#    0.11147 iters/sec. Estimated time to finish: 0:03:21.849195.
# 0           1540        1.03138     2.36582
#      total [#################################################.] 99.20%
# this epoch [#################################################.] 99.20%
#       1550 iter, 0 epoch / 1 epochs
#    0.11147 iters/sec. Estimated time to finish: 0:01:52.140940.
# 0           1550        0.530147    2.25269
#      total [#################################################.] 99.84%
# this epoch [#################################################.] 99.84%
#       1560 iter, 0 epoch / 1 epochs
#    0.11152 iters/sec. Estimated time to finish: 0:00:22.418230.
# 0           1560        0.977889    2.24009
